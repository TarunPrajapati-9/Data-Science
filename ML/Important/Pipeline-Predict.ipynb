# %%
import pickle
import numpy as np

# %%
import pickle

# Load the pipeline
with open('pipe.pkl', 'rb') as f:
    pipe = pickle.load(f)
print("Pipeline imported successfully.")
# Out:
# Pipeline imported successfully.

# %%
#Input
input_arr = np.array([2,'male',31.0,0,0,10.5,'S'],dtype=object).reshape(1,7)

# %%
pipe.predict(input_arr)
# Out:
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)
