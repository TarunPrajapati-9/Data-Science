# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("carsales.csv",usecols=['Odometer (KM)','Doors','Price'])
df.sample(5)
# Out:
#      Odometer (KM)  Doors    Price
# 579        46842.0    4.0  28655.0
# 89         90249.0    4.0  35988.0
# 899        23241.0    4.0  14203.0
# 949        57558.0    3.0  16622.0
# 198       193874.0    4.0  10596.0

# %%
df.isnull().sum()
# Out:
# Odometer (KM)    50
# Doors            50
# Price            50
# dtype: int64

# %%
df['Doors'] = df['Doors'].fillna(df['Doors'].mean())
df['Odometer (KM)'] = df['Odometer (KM)'].fillna(df['Odometer (KM)'].mean())
df['Price'] = df['Price'].fillna(df['Price'].mean())

# %%
df.isnull().sum()
# Out:
# Odometer (KM)    0
# Doors            0
# Price            0
# dtype: int64

# %%
from sklearn.preprocessing import FunctionTransformer

# %%
# ft = FunctionTransformer(func= lambda x: x**2)
ft = FunctionTransformer(func= np.log1p)

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

# %%
x = df.iloc[:,0:2]
y = df.iloc[:,2]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

x_train.shape, x_test.shape,y_train.shape, y_test.shape
# Out:
# ((800, 2), (200, 2), (800,), (200,))

# %%
x_train_transformed = ft.fit_transform(x_train)
x_test_transformed = ft.transform(x_test)

print(x_test_transformed.shape)
# Out:
# (200, 2)

# %%
lr = LinearRegression()

# %%
lr.fit(x_train_transformed,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test_transformed)
y_pred
# Out:
# array([ 9947.26167636, 13285.49765031, 21549.5510825 , 16633.76829246,
#        20564.35311719, 13447.78136985, 13099.85999166, 15214.74885126,
#        10041.67847796, 15192.29431986, 20033.91628838, 14965.25148807,
#        21471.60152976, 13074.9222945 , 14922.57795743, 22075.1683742 ,
#        15663.63267408, 15992.7358528 , 17960.19161926, 11405.7676569 ,
#        20559.66701875, 13893.49162233, 22019.76871702, 13149.19251245,
#        21805.19916575, 15214.74885126, 13273.1548511 , 17486.50944788,
#        19987.49494619, 23273.97714983, 19738.86636867, 15050.72645152,
#        15040.16435798, 16962.37741842, 17521.70583126, 13797.6292825 ,
#        13145.64023281, 16413.31102728,  9645.65091144, 13176.12116012,
#        15108.87874349, 21018.72030865, 24929.50270921, 14596.41146026,
#        16139.60881705, 16073.39442473, 11952.10733516, 12930.23328545,
#        18243.34017785, 17851.40206407, 13442.68531321, 13087.80667256,
#        18089.09321502, 13413.18029629, 15248.01693258, 20476.77574383,
#        12898.33274878, 14325.57985876, 10709.91995458, 16195.40832097,
#        15153.82183835, 15891.78154559, 19884.93262265, 15214.74885126,
#        21494.13926764, 19018.32685717, 13092.6942654 , 18712.12314429,
#        15451.23105419, 13509.27831542, 13968.15090919, 19615.49167103,
#        13401.82500292, 17253.16997777, 13729.2609548 , 13426.76927608,
#        19024.80073972, 15875.26623818, 13497.95950043, 10360.24376949,
