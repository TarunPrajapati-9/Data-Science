# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("50_AdAgency.csv")
dataset.head(13)
# Out:
#     Print Media Expenses  Social Media Expenses     Profit
# 0              165349.20              136897.80  192261.83
# 1              162597.70              151377.59  191792.06
# 2              153441.51              101145.55  191050.39
# 3              144372.41              118671.85  182901.99
# 4              142107.34               91391.77  166187.94
# 5              131876.90               99814.71  156991.12
# 6              134615.46              147198.87  156122.51
# 7              130298.13              145530.06  155752.60
# 8              120542.52              148718.95  152211.77
# 9              123334.88              108679.17  149759.96
# 10             101913.08              110594.11  146121.95
# 11             100671.96               91790.61  144259.40
# 12              93863.75              127320.38  141585.52

# %%
sns.pairplot(data=dataset)
plt.show()

# %%
sns.heatmap(data=dataset.corr(),annot=True)
plt.savefig("MultipleRegression.jpg")
plt.show()

# %%
dataset.shape
# Out:
# (50, 3)

# %%
x = dataset.iloc[:,:-1]
y = dataset["Profit"]
x.ndim
# Out:
# 2

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x.columns
# Out:
# Index(['Print Media Expenses', 'Social Media Expenses'], dtype='object')

# %%
lr.score(x_test,y_test)*100
# Out:
# 89.65609365509309

# %%
lr.coef_ , lr.intercept_
# Out:
# (array([ 0.86231873, -0.09716476]), 60430.8591328396)

# %%
# y = m1x1 + m2x2 + c
# y = 0.86231873*Print Media Expenses - 0.09716476*Social Media Expenses + 60430.8591328396

# %%
lr.predict(x_test)
# Out:
# array([126592.27420404,  85617.64976261, 102653.60331559,  49230.07617661,
#        127959.07301964,  55870.66838015, 111383.4169182 , 102632.80063112,
#        102553.91453647, 120036.02360374])

# %%
lr.predict([[93863.75,127320.38]])
# Out:
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([129000.27474888])
