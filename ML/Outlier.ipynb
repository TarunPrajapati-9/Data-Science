# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("carsales.csv")

# %%
dataset.describe()
# Out:
#        Odometer (KM)       Doors         Price
# count     950.000000  950.000000    950.000000
# mean   131253.237895    4.011579  16042.814737
# std     69094.857187    0.382539   8581.695036
# min     10148.000000    3.000000   2796.000000
# 25%     70391.250000    4.000000   9529.250000
# 50%    131821.000000    4.000000  14297.000000
# 75%    192668.500000    4.000000  20806.250000
# max    249860.000000    5.000000  52458.000000

# %%
sns.boxplot(x= "Price",data=dataset)
plt.show()

# %%
sns.distplot(dataset["Price"])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_90516\3902254670.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["Price"])
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %% [markdown]
# Outlier Impact

# %%
salary = [5000,6000,6500,5500,5200]
sum(salary)/len(salary)
# Out:
# 5640.0

# %%
salary = [5000,6000,6500,5500,5200,600000] #60000 Outliers
sum(salary)/len(salary)
# Out:
# 104700.0
